# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense,Embedding
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/thang/data1.csv", sep=";",names=["sent", "sentiment"])
df= df.sample(n=50000, random_state=42)

# %%
# Chia tập train (80%) và tập còn lại (20%)
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df["sentiment"])

# Chia tiếp tập còn lại (20%) thành validation (10%) và test (10%)
valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df["sentiment"])

# Kiểm tra kích thước từng tập
print(f"Train size: {len(train_df)}")
print(f"Validation size: {len(valid_df)}")
print(f"Test size: {len(test_df)}")
possible_sentiments = df.sentiment.unique()

sentiment_dict = {}
for index, possible_sentiments in enumerate(possible_sentiments):
    sentiment_dict[possible_sentiments] = index

print(sentiment_dict)

train_df['label'] = df.sentiment.replace(sentiment_dict)
df.head(20)

valid_df['label'] = valid_df.sentiment.replace(sentiment_dict)
valid_df.head(20)

test_df['label'] = test_df.sentiment.replace(sentiment_dict)
test_df.head(20)
# Out:
# Train size: 40000
# Validation size: 5000
# Test size: 5000
# {'positive': 0, 'negative': 1}
# <ipython-input-4-68b421a7cd48>:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_df['label'] = df.sentiment.replace(sentiment_dict)
# <ipython-input-4-68b421a7cd48>:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   valid_df['label'] = valid_df.sentiment.replace(sentiment_dict)
# <ipython-input-4-68b421a7cd48>:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df['label'] = test_df.sentiment.replace(sentiment_dict)
#                                                     sent sentiment  label
# 29304  phim làm rất tệ, các cảnh hành động/bạo lực lố...  negative      1
# 11033  Zentropa có nhiều điểm chung với Người đàn ông...  positive      0
# 3430   Thật sai lầm khi coi bất kỳ bộ phim nào của th...  positive      0
# 42021  Tiền đề rất hấp dẫn, nhưng thật đáng buồn là b...  negative      1
# 5792   Barney không dạy bọn trẻ gì cả!!! Dưới đây là ...  negative      1
# 22118  *Cảnh báo: 1 spoiler nhỏ không quan trọng* Bạn...  negative      1
# 43133  Born Again là một tập dưới tiêu chuẩn từ phần ...  negative      1
# 27405  Mulva bị Teen Ape đưa vào tình trạng sugercoma...  negative      1
# 45378  Được rồi, tôi đã đánh dấu phần spoiler này nên...  positive      0
# 4284   Vậy đây là "Phim dành cho truyền hình" của HBO...  negative      1
# 23034  Samuel Fuller's Pickup on South Street thật dị...  positive      0
# 33436  Đã xem bộ phim này trên SBS TV ở Úc vào tuần t...  positive      0
# 45053  Gray có thể làm cho ngôn ngữ tiếng Anh nhảy qu...  positive      0
# 1259   Ngay cả đối với một mô hình phim mệt mỏi là ch...  negative      1
# 30951  Tập này nhàm chán và thậm chí không thuộc lĩnh...  negative      1
# 29404  Bộ phim này là một trong những bộ phim hay nhấ...  positive      0
# 39514  Tôi chỉ xem bộ phim này, do nhầm lẫn. Thật là ...  positive      0
# 23276  Được sản xuất vào năm 1946 và phát hành vào nă...  positive      0
# 16520  "Maléfique" là một ví dụ về cách một bộ phim k...  positive      0
# 34901  Tôi yêu thích truyện ma nói chung, nhưng TÔI Đ...  positive      0

# %%
X_train = pd.DataFrame(train_df, columns=['sent'])
X_dev = pd.DataFrame(valid_df, columns=['sent'])
X_test = pd.DataFrame(test_df, columns=['sent'])
y_train = pd.DataFrame(train_df, columns=['label'])
y_dev = pd.DataFrame(valid_df, columns=['label'])
y_test = pd.DataFrame(test_df, columns=['label'])

# %%
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
phobert = AutoModel.from_pretrained("vinai/phobert-base").to("cuda")

def get_phobert_embeddings(texts, batch_size=256):
    phobert.eval()
    all_embeddings = []

    # Tokenize toàn bộ dữ liệu
    encodings = tokenizer(texts, return_tensors="pt", truncation=True, padding=True, max_length=256)

    # Tạo DataLoader để batch xử lý
    dataset = torch.utils.data.TensorDataset(encodings["input_ids"], encodings["attention_mask"])
    dataloader = DataLoader(dataset, batch_size=batch_size)

    total_samples = len(texts)
    processed_samples = 0

    with torch.no_grad():
        for batch in dataloader:
            input_ids, attention_mask = [t.to("cuda") for t in batch]
            outputs = phobert(input_ids, attention_mask=attention_mask)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1)
            all_embeddings.append(batch_embeddings.cpu().numpy())

            # Cập nhật số lượng mẫu đã xử lý
            processed_samples += len(input_ids)
            print(f"Processed {processed_samples}/{total_samples} samples...")

    return np.vstack(all_embeddings)

# Chạy và hiển thị tiến trình
X_train = get_phobert_embeddings(X_train["sent"].tolist())
X_dev = get_phobert_embeddings(X_dev["sent"].tolist())
X_test = get_phobert_embeddings(X_test["sent"].tolist())

print("Shape of X_train:", X_train.shape)
print("Shape of X_dev:", X_dev.shape)
print("Shape of X_test", X_test.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/557 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.13M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/543M [00:00<?, ?B/s]
# Processed 256/40000 samples...
# Processed 512/40000 samples...
# Processed 768/40000 samples...
# Processed 1024/40000 samples...
# Processed 1280/40000 samples...
# Processed 1536/40000 samples...
# Processed 1792/40000 samples...
# Processed 2048/40000 samples...
# Processed 2304/40000 samples...
# Processed 2560/40000 samples...
# Processed 2816/40000 samples...
# Processed 3072/40000 samples...
# Processed 3328/40000 samples...
# Processed 3584/40000 samples...
# Processed 3840/40000 samples...
# Processed 4096/40000 samples...
# Processed 4352/40000 samples...
# Processed 4608/40000 samples...
# Processed 4864/40000 samples...
# Processed 5120/40000 samples...
# Processed 5376/40000 samples...
# Processed 5632/40000 samples...
# Processed 5888/40000 samples...
# Processed 6144/40000 samples...
# Processed 6400/40000 samples...
# Processed 6656/40000 samples...
# Processed 6912/40000 samples...
# Processed 7168/40000 samples...
# Processed 7424/40000 samples...
# Processed 7680/40000 samples...
# Processed 7936/40000 samples...
# Processed 8192/40000 samples...
# Processed 8448/40000 samples...
# Processed 8704/40000 samples...
# Processed 8960/40000 samples...
# Processed 9216/40000 samples...
# Processed 9472/40000 samples...
# Processed 9728/40000 samples...
# Processed 9984/40000 samples...
# Processed 10240/40000 samples...
# Processed 10496/40000 samples...
# Processed 10752/40000 samples...
# Processed 11008/40000 samples...
# Processed 11264/40000 samples...
# Processed 11520/40000 samples...
# Processed 11776/40000 samples...
# Processed 12032/40000 samples...
# Processed 12288/40000 samples...
# Processed 12544/40000 samples...
# Processed 12800/40000 samples...
# Processed 13056/40000 samples...
# Processed 13312/40000 samples...
# Processed 13568/40000 samples...
# Processed 13824/40000 samples...
# Processed 14080/40000 samples...
# Processed 14336/40000 samples...
# Processed 14592/40000 samples...
# Processed 14848/40000 samples...
# Processed 15104/40000 samples...
# Processed 15360/40000 samples...
# Processed 15616/40000 samples...
# Processed 15872/40000 samples...
# Processed 16128/40000 samples...
# Processed 16384/40000 samples...
# Processed 16640/40000 samples...
# Processed 16896/40000 samples...
# Processed 17152/40000 samples...
# Processed 17408/40000 samples...
# Processed 17664/40000 samples...
# Processed 17920/40000 samples...
# Processed 18176/40000 samples...
# Processed 18432/40000 samples...
# Processed 18688/40000 samples...
# Processed 18944/40000 samples...
# Processed 19200/40000 samples...
# Processed 19456/40000 samples...
# Processed 19712/40000 samples...
# Processed 19968/40000 samples...
# Processed 20224/40000 samples...
# Processed 20480/40000 samples...
# Processed 20736/40000 samples...
# Processed 20992/40000 samples...
# Processed 21248/40000 samples...
# Processed 21504/40000 samples...
# Processed 21760/40000 samples...
# Processed 22016/40000 samples...
# Processed 22272/40000 samples...
# Processed 22528/40000 samples...
# Processed 22784/40000 samples...
# Processed 23040/40000 samples...
# Processed 23296/40000 samples...
# Processed 23552/40000 samples...
# Processed 23808/40000 samples...
# Processed 24064/40000 samples...
# Processed 24320/40000 samples...
# Processed 24576/40000 samples...
# Processed 24832/40000 samples...
# Processed 25088/40000 samples...
# Processed 25344/40000 samples...
# Processed 25600/40000 samples...
# Processed 25856/40000 samples...
# Processed 26112/40000 samples...
# Processed 26368/40000 samples...
# Processed 26624/40000 samples...
# Processed 26880/40000 samples...
# Processed 27136/40000 samples...
# Processed 27392/40000 samples...
# Processed 27648/40000 samples...
# Processed 27904/40000 samples...
# Processed 28160/40000 samples...
# Processed 28416/40000 samples...
# Processed 28672/40000 samples...
# Processed 28928/40000 samples...
# Processed 29184/40000 samples...
# Processed 29440/40000 samples...
# Processed 29696/40000 samples...
# Processed 29952/40000 samples...
# Processed 30208/40000 samples...
# Processed 30464/40000 samples...
# Processed 30720/40000 samples...
# Processed 30976/40000 samples...
# Processed 31232/40000 samples...
# Processed 31488/40000 samples...
# Processed 31744/40000 samples...
# Processed 32000/40000 samples...
# Processed 32256/40000 samples...
# Processed 32512/40000 samples...
# Processed 32768/40000 samples...
# Processed 33024/40000 samples...
# Processed 33280/40000 samples...
# Processed 33536/40000 samples...
# Processed 33792/40000 samples...
# Processed 34048/40000 samples...
# Processed 34304/40000 samples...
# Processed 34560/40000 samples...
# Processed 34816/40000 samples...
# Processed 35072/40000 samples...
# Processed 35328/40000 samples...
# Processed 35584/40000 samples...
# Processed 35840/40000 samples...
# Processed 36096/40000 samples...
# Processed 36352/40000 samples...
# Processed 36608/40000 samples...
# Processed 36864/40000 samples...
# Processed 37120/40000 samples...
# Processed 37376/40000 samples...
# Processed 37632/40000 samples...
# Processed 37888/40000 samples...
# Processed 38144/40000 samples...
# Processed 38400/40000 samples...
# Processed 38656/40000 samples...
# Processed 38912/40000 samples...
# Processed 39168/40000 samples...
# Processed 39424/40000 samples...
# Processed 39680/40000 samples...
# Processed 39936/40000 samples...
# Processed 40000/40000 samples...
# Processed 256/5000 samples...
# Processed 512/5000 samples...
# Processed 768/5000 samples...
# Processed 1024/5000 samples...
# Processed 1280/5000 samples...
# Processed 1536/5000 samples...
# Processed 1792/5000 samples...
# Processed 2048/5000 samples...
# Processed 2304/5000 samples...
# Processed 2560/5000 samples...
# Processed 2816/5000 samples...
# Processed 3072/5000 samples...
# Processed 3328/5000 samples...
# Processed 3584/5000 samples...
# Processed 3840/5000 samples...
# Processed 4096/5000 samples...
# Processed 4352/5000 samples...
# Processed 4608/5000 samples...
# Processed 4864/5000 samples...
# Processed 5000/5000 samples...
# Processed 256/5000 samples...
# Processed 512/5000 samples...
# Processed 768/5000 samples...
# Processed 1024/5000 samples...
# Processed 1280/5000 samples...
# Processed 1536/5000 samples...
# Processed 1792/5000 samples...
# Processed 2048/5000 samples...
# Processed 2304/5000 samples...
# Processed 2560/5000 samples...
# Processed 2816/5000 samples...
# Processed 3072/5000 samples...
# Processed 3328/5000 samples...
# Processed 3584/5000 samples...
# Processed 3840/5000 samples...
# Processed 4096/5000 samples...
# Processed 4352/5000 samples...
# Processed 4608/5000 samples...
# Processed 4864/5000 samples...
# Processed 5000/5000 samples...
# Shape of X_train: (40000, 768)
# Shape of X_dev: (5000, 768)
# Shape of X_test (5000, 768)

# %%
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_dev = X_dev.reshape((X_dev.shape[0], 1, X_dev.shape[1]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional

model = Sequential([
    Bidirectional(LSTM(128, return_sequences=True), input_shape=(1, X_train.shape[2])),
    Dropout(0.5),
    Bidirectional(LSTM(32, return_sequences=False)),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(16, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # Assuming 3 output classes
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
X_train = X_train.astype(float)
y_train = y_train.astype(float)

X_dev = X_dev.astype(float)
y_dev = y_dev.astype(float)

# %%
history = model.fit(
    X_train,  # Dữ liệu huấn luyện
    y_train,  # Nhãn huấn luyện
    epochs=30,  # Số epochs
    batch_size=256,# Kích thước batch
    validation_data=(X_dev, y_dev)  # Dữ liệu validation
)
# Out:
# Epoch 1/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.5180 - loss: 0.8453 - val_accuracy: 0.8108 - val_loss: 0.4200
# Epoch 2/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7827 - loss: 0.5116 - val_accuracy: 0.8122 - val_loss: 0.4147
# Epoch 3/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8009 - loss: 0.4658 - val_accuracy: 0.8244 - val_loss: 0.3869
# Epoch 4/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8100 - loss: 0.4483 - val_accuracy: 0.8212 - val_loss: 0.3844
# Epoch 5/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8141 - loss: 0.4390 - val_accuracy: 0.8304 - val_loss: 0.3744
# Epoch 6/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8186 - loss: 0.4261 - val_accuracy: 0.8300 - val_loss: 0.3713
# Epoch 7/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8219 - loss: 0.4169 - val_accuracy: 0.8286 - val_loss: 0.3794
# Epoch 8/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8189 - loss: 0.4236 - val_accuracy: 0.8318 - val_loss: 0.3680
# Epoch 9/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8257 - loss: 0.4079 - val_accuracy: 0.8270 - val_loss: 0.3746
# Epoch 10/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8301 - loss: 0.4015 - val_accuracy: 0.8322 - val_loss: 0.3682
# Epoch 11/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8284 - loss: 0.4013 - val_accuracy: 0.8322 - val_loss: 0.3660
# Epoch 12/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8251 - loss: 0.4021 - val_accuracy: 0.8314 - val_loss: 0.3686
# Epoch 13/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8289 - loss: 0.3967 - val_accuracy: 0.8322 - val_loss: 0.3713
# Epoch 14/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8291 - loss: 0.3952 - val_accuracy: 0.8342 - val_loss: 0.3639
# Epoch 15/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8284 - loss: 0.3954 - val_accuracy: 0.8332 - val_loss: 0.3634
# Epoch 16/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8298 - loss: 0.3962 - val_accuracy: 0.8298 - val_loss: 0.3695
# Epoch 17/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8313 - loss: 0.3958 - val_accuracy: 0.8314 - val_loss: 0.3774
# Epoch 18/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8347 - loss: 0.3926 - val_accuracy: 0.8352 - val_loss: 0.3650
# Epoch 19/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8339 - loss: 0.3877 - val_accuracy: 0.8350 - val_loss: 0.3631
# Epoch 20/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8338 - loss: 0.3863 - val_accuracy: 0.8152 - val_loss: 0.4030
# Epoch 21/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8277 - loss: 0.3961 - val_accuracy: 0.8358 - val_loss: 0.3610
# Epoch 22/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8352 - loss: 0.3901 - val_accuracy: 0.8336 - val_loss: 0.3658
# Epoch 23/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8340 - loss: 0.3815 - val_accuracy: 0.8338 - val_loss: 0.3636
# Epoch 24/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8381 - loss: 0.3787 - val_accuracy: 0.8338 - val_loss: 0.3616
# Epoch 25/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8402 - loss: 0.3767 - val_accuracy: 0.8380 - val_loss: 0.3623
# Epoch 26/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8396 - loss: 0.3759 - val_accuracy: 0.8342 - val_loss: 0.3685
# Epoch 27/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8402 - loss: 0.3770 - val_accuracy: 0.8342 - val_loss: 0.3715
# Epoch 28/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8384 - loss: 0.3785 - val_accuracy: 0.8330 - val_loss: 0.3683
# Epoch 29/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8372 - loss: 0.3757 - val_accuracy: 0.8374 - val_loss: 0.3633
# Epoch 30/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8390 - loss: 0.3740 - val_accuracy: 0.8368 - val_loss: 0.3639

# %%
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
# Đánh giá mô hình trên dữ liệu huấn luyện

test_loss, test_accuracy = model.evaluate(X_test, y_test)

# In kết quả
print(f'Training Loss: {test_loss}')
print(f'Training Accuracy: {test_accuracy}')
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8347 - loss: 0.3744
# Training Loss: 0.3767947852611542
# Training Accuracy: 0.8330000042915344

# %%
from sklearn.metrics import classification_report
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)  # Nếu output là xác suất của nhiều lớp
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels))
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83      2500
#          1.0       0.83      0.84      0.83      2500
#
#     accuracy                           0.83      5000
#    macro avg       0.83      0.83      0.83      5000
# weighted avg       0.83      0.83      0.83      5000

# %%
sample_text = input("Nhập một câu: ")

# Chuyển câu nhập thành embedding
sample_emb = get_phobert_embeddings([sample_text])
# Reshape lại để phù hợp với input của LSTM
sample_emb = sample_emb.reshape( sample_emb.shape[0], 1, sample_emb.shape[1])

# Dự đoán
predictions = model.predict(sample_emb)

# Lấy nhãn có xác suất cao nhất
predicted_label = np.argmax(predictions, axis=1)

# Hiển thị kết quả
print(f"Nhãn dự đoán: {predicted_label[0]}")
# Out:
# Nhập một câu: a
# Processed 1/1 samples...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Nhãn dự đoán: 0

# %%
import numpy as np
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score

# Create model function
def create_model(input_shape):
    model = Sequential([
    Bidirectional(LSTM(128, return_sequences=True), input_shape=(input_shape)),
    Dropout(0.5),
    Bidirectional(LSTM(32, return_sequences=False)),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(16, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # Adjust the number of units to match your problem
    ])
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

kf = KFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
y_train = np.array(y_train)
for train_index, val_index in kf.split(X_train):
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    model1 = create_model((1, X_train_fold.shape[2]))  # Adjust input shape

    model1.fit(X_train_fold, y_train_fold, epochs=30, batch_size=256, verbose=1)  # You can adjust epochs

    y_pred_fold = model1.predict(X_val_fold)
    y_pred_fold = np.argmax(y_pred_fold, axis=1)  # Convert predictions to class labels

    accuracy = accuracy_score(y_val_fold, y_pred_fold)  # Calculate accuracy
    print(f'Cross-Validation Accuracy: {accuracy}')
    accuracies.append(accuracy)
print(f'mean Cross-Validation Accuracy: {np.mean(accuracies)}')
print(f'max Cross-Validation Accuracy: {np.max(accuracies)}')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5002 - loss: 0.8758
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7256 - loss: 0.5799
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7861 - loss: 0.4981
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8100 - loss: 0.4562
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8066 - loss: 0.4488
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8134 - loss: 0.4401
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8139 - loss: 0.4461
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8163 - loss: 0.4297
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8235 - loss: 0.4201
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8245 - loss: 0.4198
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8232 - loss: 0.4126
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8214 - loss: 0.4151
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8253 - loss: 0.4101
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8265 - loss: 0.4076
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8282 - loss: 0.4017
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8254 - loss: 0.4086
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8267 - loss: 0.3998
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8309 - loss: 0.3976
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8299 - loss: 0.4014
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8304 - loss: 0.3955
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8356 - loss: 0.3846
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8381 - loss: 0.3801
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8291 - loss: 0.3910
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8333 - loss: 0.3841
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8391 - loss: 0.3817
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8343 - loss: 0.3803
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8380 - loss: 0.3764
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8362 - loss: 0.3807
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8362 - loss: 0.3799
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8408 - loss: 0.3663
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Cross-Validation Accuracy: 0.838375
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.4918 - loss: 0.8458
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6622 - loss: 0.6301
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7804 - loss: 0.5032
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8035 - loss: 0.4713
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8104 - loss: 0.4500
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8170 - loss: 0.4354
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8134 - loss: 0.4303
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8205 - loss: 0.4260
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8209 - loss: 0.4326
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8160 - loss: 0.4244
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8248 - loss: 0.4145
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8289 - loss: 0.4066
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8253 - loss: 0.4174
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8255 - loss: 0.4131
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8300 - loss: 0.4001
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8272 - loss: 0.4045
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8296 - loss: 0.4040
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8331 - loss: 0.3929
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8326 - loss: 0.3918
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8332 - loss: 0.3901
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8332 - loss: 0.3852
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8378 - loss: 0.3823
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8307 - loss: 0.3938
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8330 - loss: 0.3893
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8352 - loss: 0.3821
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8340 - loss: 0.3915
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8358 - loss: 0.3822
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8375 - loss: 0.3808
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8387 - loss: 0.3774
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8349 - loss: 0.3843
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Cross-Validation Accuracy: 0.8385
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.5104 - loss: 0.8484
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7402 - loss: 0.5469
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7927 - loss: 0.4867
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8114 - loss: 0.4602
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8119 - loss: 0.4496
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8135 - loss: 0.4402
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8149 - loss: 0.4394
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8216 - loss: 0.4218
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8245 - loss: 0.4210
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8239 - loss: 0.4168
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8203 - loss: 0.4169
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8251 - loss: 0.4173
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8285 - loss: 0.4065
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8234 - loss: 0.4115
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8342 - loss: 0.3977
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8352 - loss: 0.3932
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8317 - loss: 0.3975
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8288 - loss: 0.3983
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8338 - loss: 0.3940
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8346 - loss: 0.3875
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8347 - loss: 0.3883
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8325 - loss: 0.3872
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8385 - loss: 0.3802
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8364 - loss: 0.3824
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8362 - loss: 0.3803
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8368 - loss: 0.3822
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8370 - loss: 0.3811
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8418 - loss: 0.3640
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8352 - loss: 0.3846
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8389 - loss: 0.3682
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Cross-Validation Accuracy: 0.83175
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4610 - loss: 0.9727
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7461 - loss: 0.5888
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7874 - loss: 0.5022
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7996 - loss: 0.4690
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8128 - loss: 0.4509
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8146 - loss: 0.4425
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8151 - loss: 0.4355
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8199 - loss: 0.4270
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8175 - loss: 0.4274
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8215 - loss: 0.4190
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8241 - loss: 0.4121
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8289 - loss: 0.4090
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8305 - loss: 0.4016
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8281 - loss: 0.4076
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8288 - loss: 0.3975
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8293 - loss: 0.3977
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8314 - loss: 0.4007
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8336 - loss: 0.3902
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8332 - loss: 0.3917
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8335 - loss: 0.3911
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8282 - loss: 0.3899
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8378 - loss: 0.3833
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8367 - loss: 0.3814
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8327 - loss: 0.3843
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8381 - loss: 0.3792
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8395 - loss: 0.3749
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8413 - loss: 0.3783
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8387 - loss: 0.3787
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8340 - loss: 0.3779
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8409 - loss: 0.3715
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Cross-Validation Accuracy: 0.8295
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5206 - loss: 0.9071
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7581 - loss: 0.5682
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7855 - loss: 0.4942
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7990 - loss: 0.4653
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8014 - loss: 0.4596
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8070 - loss: 0.4462
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8095 - loss: 0.4365
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8105 - loss: 0.4315
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8181 - loss: 0.4255
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8175 - loss: 0.4229
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8266 - loss: 0.4079
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8251 - loss: 0.4069
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8254 - loss: 0.4110
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8276 - loss: 0.4027
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8280 - loss: 0.4026
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8287 - loss: 0.4024
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8367 - loss: 0.3907
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8309 - loss: 0.3932
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8295 - loss: 0.3927
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8391 - loss: 0.3846
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8340 - loss: 0.3869
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8352 - loss: 0.3829
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8339 - loss: 0.3828
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8317 - loss: 0.3889
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8386 - loss: 0.3800
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8361 - loss: 0.3801
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8379 - loss: 0.3806
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8359 - loss: 0.3797
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8400 - loss: 0.3809
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8393 - loss: 0.3781
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Cross-Validation Accuracy: 0.83475
# mean Cross-Validation Accuracy: 0.8345749999999998
# max Cross-Validation Accuracy: 0.8385

# %%
y_pred = model1.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels))
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.86      0.83      2500
#          1.0       0.85      0.80      0.82      2500
#
#     accuracy                           0.83      5000
#    macro avg       0.83      0.83      0.83      5000
# weighted avg       0.83      0.83      0.83      5000
